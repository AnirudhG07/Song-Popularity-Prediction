# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, OneHotEncoder, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer, KNNImputer
import optuna
import xgboost as xgb

# ------------------ Load Data ------------------
train = pd.read_csv("./data/train.csv")
test = pd.read_csv("./data/test.csv")

X = train.drop(columns=["song_popularity"])
y = train["song_popularity"]
test_ids = test["id"]
X_test = test.drop(columns=["id"])

# ------------------ Feature Engineering ------------------
def feature_engineering(df):
    df = df.copy()
    df["energy_dance"] = df["energy"] * df["danceability"]
    df["speech_instr"] = df["speechiness"] * (1 - df["instrumentalness"])
    df["log_duration"] = np.log1p(df["song_duration_ms"].fillna(df["song_duration_ms"].median()))
    df["log_tempo"] = np.log1p(df["tempo"].fillna(df["tempo"].median()))
    return df

feat_engineer = FunctionTransformer(feature_engineering)

num_cols = ["song_duration_ms","acousticness","danceability","energy",
            "instrumentalness","liveness","loudness","speechiness",
            "tempo","audio_valence","energy_dance","speech_instr","log_duration","log_tempo"]
cat_cols = ["key","audio_mode","time_signature"]

num_transformer = Pipeline([
    ("imputer", KNNImputer(n_neighbors=5)),
    ("scaler", StandardScaler())
])
cat_transformer = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer([
    ("num", num_transformer, num_cols),
    ("cat", cat_transformer, cat_cols)
])

# ------------------ AutoXGBoost with Optuna ------------------
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
        "gamma": trial.suggest_float("gamma", 0.0, 5.0),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.0, 5.0),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 5.0),
        "tree_method": "gpu_hist",    # GPU training
        "predictor": "gpu_predictor", # GPU inference
        "eval_metric": "logloss",
        "use_label_encoder": False
    }
    
    # Build pipeline
    model = Pipeline([
        ("features", feat_engineer),
        ("preprocessor", preprocessor),
        ("clf", xgb.XGBClassifier(**params))
    ])
    
    cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    scores = []
    for train_idx, valid_idx in cv.split(X, y):
        model.fit(X.iloc[train_idx], y.iloc[train_idx])
        scores.append(model.score(X.iloc[valid_idx], y.iloc[valid_idx]))
    
    return np.mean(scores)

# Run optimization
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=30)  # you can increase to 100+ if time permits
print("Best params:", study.best_params)

# ------------------ Train Final Model ------------------
best_params = study.best_params
best_params.update({
    "tree_method": "gpu_hist",
    "predictor": "gpu_predictor",
    "eval_metric": "logloss",
    "use_label_encoder": False
})

final_model = Pipeline([
    ("features", feat_engineer),
    ("preprocessor", preprocessor),
    ("clf", xgb.XGBClassifier(**best_params))
])
# Out:
# [I 2025-09-15 23:50:12,473] A new study created in memory with name: no-name-5c35d7e4-9c24-464c-8c80-0bd43586a79d
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:19] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:50:24] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:729: UserWarning: [23:50:24] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:50:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:42] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:50:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# [I 2025-09-15 23:50:46,954] Trial 0 finished with value: 0.6340333333333334 and parameters: {'n_estimators': 517, 'max_depth': 7, 'learning_rate': 0.020210697615438675, 'subsample': 0.8845532655340733, 'colsample_bytree': 0.6842914963437824, 'gamma': 3.321634358042062, 'reg_lambda': 3.3092674268595617, 'reg_alpha': 1.7021129002849278}. Best is trial 0 with value: 0.6340333333333334.
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:53] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:50:53] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:50:56] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:02] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:02] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:51:05] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:12] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:12] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:51:15] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# [I 2025-09-15 23:51:15,429] Trial 1 finished with value: 0.6330333333333332 and parameters: {'n_estimators': 774, 'max_depth': 12, 'learning_rate': 0.10240030486480563, 'subsample': 0.9664705083629914, 'colsample_bytree': 0.7777968802122314, 'gamma': 3.8056647564094175, 'reg_lambda': 4.477128653642637, 'reg_alpha': 2.1163781306912504}. Best is trial 0 with value: 0.6340333333333334.
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:21] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:21] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:51:24] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:30] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:30] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:51:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:39] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:39] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:51:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# [I 2025-09-15 23:51:43,003] Trial 2 finished with value: 0.6356 and parameters: {'n_estimators': 313, 'max_depth': 8, 'learning_rate': 0.06053636126571664, 'subsample': 0.9603193211104045, 'colsample_bytree': 0.8942892479306304, 'gamma': 4.750606116191978, 'reg_lambda': 3.408202680370697, 'reg_alpha': 4.842359561984047}. Best is trial 2 with value: 0.6356.
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:49] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:49] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:51:53] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:59] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:51:59] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:52:02] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:52:08] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:52:08] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:52:11] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# [I 2025-09-15 23
28] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:56:34] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:56:34] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:56:37] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# [I 2025-09-15 23:56:37,667] Trial 12 finished with value: 0.6356333333333334 and parameters: {'n_estimators': 355, 'max_depth': 3, 'learning_rate': 0.010308924975620484, 'subsample': 0.745360065171947, 'colsample_bytree': 0.8966662825153288, 'gamma': 1.9067128555717767, 'reg_lambda': 1.5890719951538053, 'reg_alpha': 3.7769798872386113}. Best is trial 11 with value: 0.6356333333333334.
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:56:43] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [23:56:43] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [23:56:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# ...
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:02:43] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:02:43] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:02:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# [I 2025-09-16 00:02:46,586] Trial 25 finished with value: 0.6339333333333333 and parameters: {'n_estimators': 348, 'max_depth': 4, 'learning_rate': 0.1443799565731634, 'subsample': 0.8803227649267885, 'colsample_bytree': 0.8202989191961528, 'gamma': 3.0057611478617705, 'reg_lambda': 1.3753521414217582, 'reg_alpha': 4.052958088355463}. Best is trial 11 with value: 0.6356333333333334.
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:02:52] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:02:52] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:02:56] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:02] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:02] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:03:05] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:11] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:03:15] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# [I 2025-09-16 00:03:15,263] Trial 26 finished with value: 0.6286666666666666 and parameters: {'n_estimators': 507, 'max_depth': 3, 'learning_rate': 0.08068227379224152, 'subsample': 0.7312667228337694, 'colsample_bytree': 0.9633375537097266, 'gamma': 2.1546847489906025, 'reg_lambda': 0.8742000478104102, 'reg_alpha': 3.4544165936653175}. Best is trial 11 with value: 0.6356333333333334.
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:21] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:21] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:03:25] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:03:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:41] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:41] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:03:45] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# [I 2025-09-16 00:03:45,654] Trial 27 finished with value: 0.6229333333333334 and parameters: {'n_estimators': 588, 'max_depth': 7, 'learning_rate': 0.038550984219164156, 'subsample': 0.7865571707132156, 'colsample_bytree': 0.9122952941855731, 'gamma': 1.5645564764057083, 'reg_lambda': 1.6980191371243247, 'reg_alpha': 4.55111029580113}. Best is trial 11 with value: 0.6356333333333334.
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:51] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:03:51] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:03:55] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:01] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:01] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:04:05] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:11] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:11] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:04:15] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# [I 2025-09-16 00:04:15,786] Trial 28 finished with value: 0.6346666666666666 and parameters: {'n_estimators': 957, 'max_depth': 10, 'learning_rate': 0.012794933774094174, 'subsample': 0.8346773071316324, 'colsample_bytree': 0.7332502684927216, 'gamma': 4.3297996815440705, 'reg_lambda': 3.0277282784075, 'reg_alpha': 2.929604255518389}. Best is trial 11 with value: 0.6356333333333334.
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:21] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:21] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:04:25] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:31] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:04:34] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:40] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:40] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:04:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# [I 2025-09-16 00:04:44,174] Trial 29 finished with value: 0.6346333333333334 and parameters: {'n_estimators': 522, 'max_depth': 5, 'learning_rate': 0.01987693016028358, 'subsample': 0.9175181701897134, 'colsample_bytree': 0.8262789088170548, 'gamma': 3.5461458566873176, 'reg_lambda': 2.3667080169622134, 'reg_alpha': 1.3641352459505363}. Best is trial 11 with value: 0.6356333333333334.
# Best params: {'n_estimators': 259, 'max_depth': 3, 'learning_rate': 0.010183083254484622, 'subsample': 0.6064891012539207, 'colsample_bytree': 0.9089055214863802, 'gamma': 1.8277033804498453, 'reg_lambda': 1.93012522932704, 'reg_alpha': 4.967521448186203}

# %%
final_model.fit(X, y)
# Out:
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:57] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [00:04:57] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "predictor", "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Pipeline(steps=[('features',
#                  FunctionTransformer(func=<function feature_engineering at 0x7ea24d780ea0>)),
#                 ('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    KNNImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['song_duration_ms',
#                                                    'acousticness',
#                                                    'danceability', 'energy',
#                                                    'instrumentalness',
#                                                    'liveness', 'loudness',
#                                                    'speechiness', 'tempo',
#                                                    '...
#                                gamma=1.8277033804498453, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.010183083254484622, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=3,
#                                max_leaves=None, min_child_weight=None,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=259,
#                                n_jobs=None, num_parallel_tree=None, ...))])

# %%
# ------------------ Predict Test ------------------
test_preds = final_model.predict(X_test)

submission = pd.DataFrame({
    "id": test_ids,
    "song_popularity": test_preds
})
submission.to_csv("submission_3.csv", index=False)
print("✅ submission.csv created with AutoXGBoost + GPU")
# Out:
# ✅ submission.csv created with AutoXGBoost + GPU
# /home/anirudhgupta/main/umc301/kaggle1/.venv/lib/python3.12/site-packages/xgboost/core.py:2676: UserWarning: [00:05:03] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
